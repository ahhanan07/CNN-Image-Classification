# %% [markdown]
# # <span style="color:#0b486b">Machine Learning, Deep Neural Networks and CNNs</span>

# %% [markdown]
# ## <span style="color:#0b486b">Part 1: Theory and Knowledge Questions</span>
# <div style="text-align: right"><span style="color:red; font-weight:bold"></div>

# %% [markdown]
# The first part of this assignment is for you to demonstrate your knowledge in deep learning that you have acquired from the lectures and tutorials materials. Most of the contents in this assignment are drawn from the tutorials covered from weeks 1 to 3. Going through these materials before attempting this part is highly recommended.

# %% [markdown]
# ####  <span style="color:red">**Question 1.1.**</span> **Activation function plays an important role in modern Deep NNs. For each of the activation function below, state its output range and find its derivative (show your steps)**
#
# <span style="color:red">**(a)**</span> Sigmoid: $\sigma(x) = \frac{1}{1+\text{exp}{(-x)}}$
# <div style="text-align: right"><span style="color:red"></span></div>
#
#
#
# \begin{equation} \text{Applying derivative w.r.t x:} \end{equation}
#
# \begin{equation} \frac{d \sigma(x)}{dx} = \frac{d (\frac{1}{1+e^{-x}})}{dx} \end{equation}
#
# \begin{equation} \text{Applying Quotient rule to the above equation} => \frac{d (\frac{f(x)}{g(x)})}{dx} = \frac{g(x)*\frac{df(x)}{dx} - f(x)*\frac{dg(x)}{dx}}{(g(x))^2} \end{equation}
#
# \begin{equation} \frac{d \sigma(x)}{dx} =  \frac{((1+e^{-x})*0) - (1*(-e^{-x}))}{(1+e^{-x})^2} \end{equation}
#
# \begin{equation} => \frac{d \sigma(x)}{dx} = \frac{e^{-x}}{(1+e^{-x})^2} \end{equation}
#
# \begin{equation} \text{Simplifying the equation we get :} \end{equation}
#
# \begin{equation} => \frac{d \sigma(x)}{dx} = \frac{1-1+e^{-x}}{(1+e^{-x})^2} \end{equation}
#
# \begin{equation} => \frac{d \sigma(x)}{dx} = \frac{1+e^{-x}}{(1+e^{-x})^2} - \frac{1}{(1+e^{-x})^2}\end{equation}
#
# \begin{equation} => \frac{d \sigma(x)}{dx} = \frac{1}{(1+e^{-x})} - \frac{1}{(1+e^{-x})^2}\end{equation}
#
# \begin{equation} => \frac{d \sigma(x)}{dx} = \frac{1}{1+e^{-x}}[1 - \frac{1}{1+e^{-x}}]\end{equation}
#
# \begin{equation} \text{We know,} \frac{1}{(1+e^{-x})} = \sigma(x) \end{equation}
#
# \begin{equation} \frac{d \sigma(x)}{dx} =  \sigma(x)*[1 - \sigma(x)]        \end{equation}
#
# \begin{equation} \text{Derivative(sigmoid activation) = } (\sigma(x)*[1 - \sigma(x)])  \end{equation}
#
# \begin{equation} \text{Output range of the sigmoid function is (0,1)} \end{equation}
#
# \begin{equation} \space{} \end{equation}
#
# \begin{equation} \space{} \end{equation}
#
# <span style="color:red">**(b)**</span> Tanh: $\sigma(x) = \frac{\exp(x) - \exp{(-x)}}{\exp(x) + \exp{(-x)}}= \frac{1-\exp(-2x)}{1+\exp(-2x)}$
# <div style="text-align: right"><span style="color:red"></span></div>
# \begin{equation} \text{Applying derivative w.r.t x:} \end{equation}
#
# \begin{equation} \frac{d \sigma(x)}{dx} = \frac{d (\frac{e^{x} - e^{-x}}{e^{x} + e^{-x}})}{dx} \text{   -- 1st equation} \end{equation}
#
# \begin{equation} \text{Applying Quotient rule to the above equation} => \frac{d (\frac{f(x)}{g(x)})}{dx} = \frac{g(x)*\frac{df(x)}{dx} - f(x)*\frac{dg(x)}{dx}}{(g(x))^2} \end{equation}
#
# \begin{equation} \frac{d \sigma(x)}{dx} =  \frac{((e^x+e^{-x})*(e^x+e^{-x})) - ((e^x-e^{-x})*((e^x-e^{-x})))}{(e^x+e^{-x})^2} \end{equation}
#
# \begin{equation} \frac{d \sigma(x)}{dx} =  \frac{(e^x+e^{-x})^2 - (e^x-e^{-x})^2}{(e^x+e^{-x})^2} \end{equation}
#
# \begin{equation} \frac{d \sigma(x)}{dx} =  \frac{(e^x+e^{-x})^2}{(e^x+e^{-x})^2} - \frac{(e^x-e^{-x})^2}{(e^x+e^{-x})^2} \end{equation}
#
# \begin{equation} \frac{d \sigma(x)}{dx} =  1 - (\frac{e^x-e^{-x}}{e^x+e^{-x}})^2 \end{equation}
#
# \begin{equation} \frac{d \sigma(x)}{dx} = 1 - (\sigma(x))^2  \end{equation}
#
# \begin{equation} \text{Derivative(tanh activation) = } (1 - (\tanh(x))^2)  \end{equation}
#
# \begin{equation} \text{Output range of the function is [-1,1]} \end{equation}

# %% [markdown]
# <span style="color:#0b486b"> **Numpy is going to be used in the following questions. You need to import numpy here.** </span>

# %%
import numpy as np

# %% [markdown]
# ####  <span style="color:red">**Question 1.2.**</span> **Softmax activation aims to transform discriminative values to prediction probabilities. Assume that at the output layer, we obtain the logit $h^{L}$ as shown in the following cell. What is the corresonding prediction probabilities $p$? You are required to answer the formula for $p$ and write the code for computing $p$ in the following cells.**
#
# <div style="text-align: right"><span style="color:red"></span></div>

# %% [markdown]
# <span style="color:red">**Provide the formula for $p$ here**</span>
#
# - **p = $\sigma(x)_{z_i} = \frac{\text{exp}{(x_{z_i})}}{\sum_{k=1}^3{exp}{(x_{z_k})}}$**

# %% [markdown]
# The following cell contains the code to generate the logit $h^L$ using your *student ID* as the seed of numpy.

# %%
np.random.seed(30340284)  #replace 123456 with your student ID
hL = np.random.rand(3,1) 
#Insert your code to compute the prediction probability here
p = np.exp(hL)/sum(np.exp(hL))
p
# Out:
# array([[0.43975501],
#        [0.23424391],
#        [0.32600109]])

# %% [markdown]
# ####  <span style="color:red">**Question 1.3.**</span> **Linear operation and element-wise activation are two building-blocks for conducting a layer in a feedforward neural network.**
#
# <span style="color:red">**(a)**</span> **Assume that hidden layer $1$ has value $h^1(x) \in \mathbb{R}^{2 \times 1}$ whose value will be generated randomly and the weight matrix and bias at the second layer are:**
# - **$W^{2} \in \mathbb{R}^{3 \times 2}$ and $b^2 \in \mathbb{R}^{3 \times 1}$ whose values are generated randomly too.
# What is the value of the hidden layer $\bar{h}^{2}(x)$ after applying *the linear operation* with the matrix $W^2$ and the bias $b^2$ over $h^1$. Provide the formula and the code in the following cells.**
#
# <div style="text-align: right"><span style="color:red"></span></div>
#
#
# <span style="color:red">**(b)**</span> **Assume that we apply *the ReLU activation function* at the second layer. What is the value of the hidden layer $h^2(x)$ after we apply the activation function? Provide the formula and the code in the following cells.**
#
# <div style="text-align: right"><span style="color:red"></span></div>

# %% [markdown]
# <span style="color:red">**(a) Provide the formula for $\bar{h}^{2}(x)$ here**</span>
#
# -\begin{equation} \bar{h}^{2}(x) = {W}^{2}*{h}^{1}(x) + {b}^{2} \end{equation}<br>
# h1 : First Hidden layer
#
# W2 : Weights of second hidden layer
#
# b2 : Bias value of the second hidden layer

# %%
np.random.seed(30340284)  #replace 123456 with your student ID
W2 = np.random.rand(3,2)
# print("W2",W2)
b2 = np.random.rand(3,1)
# print("b2",b2)
#Insert your code to compute h1 and h{bar}2 here
h1 = np.random.rand(2,1)
h_bar_2 = np.dot(W2,h1)+b2
h_bar_2
# Out:
# array([[1.26542385],
#        [1.26871493],
#        [0.54255988]])

# %% [markdown]
# <span style="color:red">**(b) Provide the formula for ${h}^{2}(x)$ here**</span>
#
# -\begin{equation} {h}^{2}(x) = max(0, input) \end{equation}
#
# \begin{equation} {h}^{2}(x) = max(0,\bar{h}^{2}(x)) \end{equation}

# %%
#Insert your code to compute h2 here
#Note that we use ReLU activation function
def relu(h_bar):
    return (np.where(h_bar<0,0,h_bar))

h_2 = relu(h_bar_2)
h_2
# Out:
# array([[1.26542385],
#        [1.26871493],
#        [0.54255988]])

# %% [markdown]
# ####  <span style="color:red">**Question 1.4.**</span> **Given the DNN architecture below for regression task. This DNN has three layers, assuming all bias terms are zero. The input layer has dimension $M$, the output layer has dimension $K$, the hidden layer has two nodes and uses *sigmoid* activation function. Assume the weight goes from $x_m$ to $h_i$ is $w^h_{im}$, and the weight goes from $h_i$ to $y_k$ is $w^o_{ki}$. Given a single training input $(x,y)$ where $y=(y_1, \ldots,y_K)$ is a vector of $K$ dimension. Answer the following questions in regarding to back propagation procedure for this network:**
#
# <img src='Figures/dnn_reg1.png' width=230>

# %% [markdown]
# <span style="color:red">**(a)**</span> **What are the expressions to compute forward propagation for $h_1$, $h_2$ and $\hat{y}_k$?**
# <div style="text-align: right"><span style="color:red"></span></div>
# \begin{equation} h_1 = \sigma({{W_{1m}^h}}*x) \end{equation}
#
# \begin{equation} h_2 = \sigma({{W_{2m}^h}}*x) \end{equation}
#
# \begin{equation} \hat{y}_k = W_{ki} * \begin{bmatrix}
# h_1 \\
# h_2 \\
# \end{bmatrix}      \end{equation}
# ​
# \begin{equation} \hat{y}_k = W_{k1}*h_1 + W_{k2}*h_2   \end{equation}
# ​

# %% [markdown]
# <span style="color:red">**(b)**</span> **What are the stochastic gradient descent (SGD) update equation for $w^o_{11}$ and $w^o_{k1}$ in general for $k=1,\ldots,K$ (show your derivation) in case the mini-batch includes only $x= [x_1,...,x_M]$?**
# <div style="text-align: right"><span style="color:red"></span></div>
#
# \begin{equation} \hat{y}_1 = \begin{bmatrix}
# {W_{11}}^0 &  {W_{12}}^0 \\
# \end{bmatrix} * \begin{bmatrix}
# h_1 \\
# h_2
# \end{bmatrix}   \end{equation}
#
# \begin{equation} \hat{y}_1 = {W_{11}}^0*h_1 + {W_{12}}^0*h_2  \end{equation}
#
# \begin{equation} \text{Loss function:} \space{} J(w) = \frac{1 * (\hat{y_1} - y)^2}{2}   \end{equation}
#
# \begin{equation} \frac{d {J_t}(w)}{d {w_{11}}^0} = \frac{d J_t}{d \hat{y}} * \frac{d \hat{y}}{d {w_{11}}^0} = (\hat{y_1} - y) * h_1 \end{equation}
#
# \begin{equation} \space{} \end{equation}
#
# \begin{equation} \text{Stocahstic gradient descent update:} \end{equation}
#
# \begin{equation} {w_{11}}^0  \leftarrow  {w_{11}}^0 - \eta(\hat{y_1} - y)*h_1   \end{equation}
#
# **In General:**
#
# \begin{equation} {w_{k1}}^0  \leftarrow  {w_{k1}}^0 - \eta(\hat{y_k} - y)*h_1   \end{equation}

# %% [markdown]
# <span style="color:red">**(c)**</span> **What are the stochastic gradient descent (SGD) update equation for $w^h_{11}$ and $w^h_{1m}$ in general for $m=1, \ldots, M$ (show your derivation) in case the mini-batch includes only $x= [x_1,...,x_M]$?**
# <div style="text-align: right"><span style="color:red"></span></div>
#
# \begin{equation} \text{Loss function:} \space{} J(w) = \frac{1 * (\hat{y_1} - y)^2}{2}   \end{equation}
#
# \begin{equation} \frac{d J(w)}{d {w_{11}}^h} = \frac{d J(w)}{d \bar{h_1}} * \frac{d \bar{h_1}}{d {w_{11}}^h} \end{equation}
#
# \begin{equation} \frac{d J(w)}{d {w_{11}}^h} = \frac{d J(w)}{d h_1} * \frac{d h_1}{d \bar{h_1}} * \frac{d \bar{h_1}}{d {w_{11}}^h} \end{equation}
#
# \begin{equation} \frac{d J(w)}{d {w_{11}}^h} = \frac{d J(w)}{d \hat{y_k}} * \frac{d \hat{y_k}}{d h_1} *\frac{d h_1}{d \bar{h_1}} * \frac{d \bar{h_1}}{d {w_{11}}^h} \end{equation}
#
# \begin{equation} \frac{d J(w)}{d {w_{11}}^h} = (\hat{y_k}-y) * {W_{k1}}^0 * h_1(1-h_1) * x_1       \end{equation}
#
# \begin{equation} \text{Stocahstic gradient descent update:} \end{equation}
#
# \begin{equation} {w_{11}}^h  \leftarrow  {w_{11}}^h - \eta h_1 (1-h_1)*{W_{k1}}^0 (\hat{y_k} - y) * x_1   \end{equation}
# **In General:**
#
# \begin{equation} {w_{1m}}^h  \leftarrow  {w_{1m}}^h - \eta h_1 (1-h_1)*{W_{k1}}^0 (\hat{y_k} - y) * x_m   \end{equation}

# %% [markdown]
# <span style="color:red">**(d)**</span> **What are the stochastic gradient descent (SGD) update equation for $w^h_{im}$ in general for $i=1,2$ and $m=1, \ldots, M$ (show your derivation) in case the mini-batch includes only $x= [x_1,...,x_M]$?**
# <div style="text-align: right"><span style="color:red"></span></div>
#
# **In General:**
# \begin{equation} {w_{im}}^h  \leftarrow  {w_{im}}^h - \eta h_k (1-h_k)*{W_{ki}}^0 (\hat{y_k} - y) * x_m   \end{equation}
#
# \begin{equation} \space{}   \end{equation}
#
# **For i=1**
#
# \begin{equation} {w_{1m}}^h  \leftarrow  {w_{1m}}^h - \eta h_1 (1-h_1)*{W_{k1}}^0 (\hat{y_k} - y) * x_m   \end{equation}
#
# **For i=2**
#
# \begin{equation} {w_{2m}}^h  \leftarrow  {w_{2m}}^h - \eta h_2 (1-h_2)*{W_{k2}}^0 (\hat{y_k} - y) * x_m   \end{equation}

# %% [markdown]
# ## <span style="color:#0b486b">Part 2: Deep Neural Networks (DNN) </span>
# <div style="text-align: right"><span style="color:red; font-weight:bold"><span></div>

# %% [markdown]
# **The second part of this assignment is for you to demonstrate your basis knowledge in TF 1.x and feedforward neural networks that you have acquired from the lectures and tutorials materials.**
#
# **In the second part of this assignment, you are going to work with the `FashionMNIST` dataset for `image recognition task`. It has the exact same format as MNIST (70,000 grayscale images of 28 × 28 pixels each, with 10 classes), but the images represent fashion items rather than handwritten digits, so each class is more diverse, and the problem turns out to be significantly more challenging than MNIST.**

# %% [markdown]
# ####  <span style="color:red">**Question 2.1.**</span> Load the Fashion MNIST using Keras datasets
#
# <div style="text-align: right"> <span style="color:red"></span> </div>

# %% [markdown]
# We first use keras incoporated in TensorFlow 2.x for loading the training and testing sets.

# %%
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# We first use keras datasets in TF 2.x to load Fashion MNIST dataset.

# %%
fashion_mnist = keras.datasets.fashion_mnist
(X_train_full_img, y_train_full), (X_test_img, y_test) = fashion_mnist.load_data()

# %% [markdown]
# The shape of X_train_full_img is $(60000, 28, 28 )$ and that of X_test_img is $(10000, 28, 28)$. We next convert them to matrices of vectors and store in X_train_full and X_test.

# %%
num_train = X_train_full_img.shape[0]
num_test = X_test_img.shape[0]
X_train_full = X_train_full_img.reshape(num_train,-1)
X_test = X_test_img.reshape(num_test, -1)
print(X_train_full.shape, y_train_full.shape)
print(X_test.shape, y_test.shape)
# Out:
# (60000, 784) (60000,)
# (10000, 784) (10000,)

# %% [markdown]
# ####  <span style="color:red">**Question 2.2.**</span> Preprocess the dataset and split into training, validation, and testing datasets
#
# You need to write the code to address the following requirements:
# - Use $10 \%$ of X_train_full for validation and the rest of X_train_full for training. This splits X_train_full and y_train_full into X_train, y_train ($90 \%$) and X_valid, y_valid ($10 \%$).
# - Finally, scale the piels of X_train, X_valid, and X_test to $[0,1]$) (i.e., $X = X/255.0$).
#
# <div style="text-align: right"> <span style="color:red"></span> </div>

# %%
import math
N = X_train_full.shape[0]
i = math.floor(0.9*N)
X_train, y_train = X_train_full[0:i], y_train_full[0:i]
X_valid, y_valid = X_train_full[i:], y_train_full[i:]
X_train, X_valid, X_test = X_train/255.0,X_valid/255.0,X_test/255.0

# %% [markdown]
# You have now the separate training, validation, and testing sets for training your model.

# %% [markdown]
# ####  <span style="color:red">**Question 2.3.**</span> Visualize some images in the training set with labels
#
# <div style="text-align: right"> <span style="color:red"></span> </div>
#
# You are required to write the code to show the first $36$ images in X_train_full_img (which is an array of images) with labels as shown in the following figure. Note that the class names of Fashion MNIST are as follows
# - "T-shirt/top", "Trouser", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"
#
# <img src="Figures/Fashion_MNIST.png" width="350" align="center"/>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

plt.figure(figsize=(10,10))
for i in range(36):
    plt.subplot(6,6,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_train_full_img[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[y_train_full[i]])
    
plt.show()

# %% [markdown]
# ####  <span style="color:red">**Question 2.4.**</span> Write code for the dense layer
#
# <div style="text-align: right"> <span style="color:red"></span> </div>

# %% [markdown]
# We now develop a feed-forward neural networks with the architecture $784 \rightarrow 20(ReLU) \rightarrow 25(ReLU) \rightarrow 10(softmax)$. We first declare the code for the hidden layer with a linear operation and activation. Since we are implementing using TF 1.x syntax, we first import the compatible version of TF 1.x in TF 2.x.

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From C:\Users\ahhan\anaconda3\lib\site-packages\tensorflow\python\compat\v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
import numpy as np

def dense_layer(x, num_neurons, name, activation=None):
    with tf.name_scope(name):
        num_inputs = int(x.get_shape()[1])
        stddev = 2 / np.sqrt(num_inputs)
        W_init = tf.truncated_normal([num_inputs, num_neurons], stddev=stddev,dtype= tf.float32)
        b_init = tf.random.normal([num_neurons],stddev=stddev,dtype= tf.float32)
        W = tf.Variable(W_init, name= "W")
        b = tf.Variable(b_init, name="b")
        z = tf.matmul(x, W) + b
    if activation == "sigmoid":
        return tf.math.sigmoid(z)
    elif activation == "relu":
        return tf.nn.relu(z)
    else:
        return z

# %% [markdown]
# ####  <span style="color:red">**Question 2.5.**</span> Declare your network and visualize quantities of interest using TensorBoard
#
# <div style="text-align: right"> <span style="color:red"></span> </div>
#
# It is the time to implement your network with the architecture $784 \rightarrow 20(ReLU) \rightarrow 25(ReLU) \rightarrow 10(softmax)$. Note that we need to store and visualize the following quantities using TensorBoard:
# - Gradients of trainable variables (weight matrices and biases) (Hint: use method `compute_gradients` with respect to the loss function).
# - Hidden layers 1 and 2.

# %%
num_hidden1 = 20
num_hidden2 = 25
num_outputs = 10
num_inputs = 784  #28 x 28

# %% [markdown]
# *Run the following cell to create necessary subfolders for this assignment. You must **not** modify these codes and **must** run it first*.

# %%
# Create necessary subfolders to store immediate files for this assignment.

import os
if not os.path.exists("./models/dnn0"):
    os.makedirs("models/dnn0")

# %%
tf.reset_default_graph()
inputs = tf.placeholder(tf.float32, shape=[None, num_inputs], name="inputs") 
labels = tf.placeholder(tf.int32, shape=[None], name="labels") 

with tf.name_scope("dnn"):
    hidden1 = dense_layer(inputs, num_hidden1, name= "layer1", activation= "relu")
    hidden2 = dense_layer(hidden1, num_hidden2, name= "layer2", activation= "relu")
    logits = dense_layer(hidden2, num_outputs, name="logits")
    
with tf.name_scope("loss"):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=labels, logits=logits, name='xentropy')
    loss = tf.reduce_mean(xentropy, name="loss")
    
with tf.name_scope("evaluation"):
    correct =  tf.nn.in_top_k(logits, labels, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))
    
with tf.name_scope("train"):
    learning_rate = 0.001
    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
    grads = optimizer.compute_gradients(loss)
    training_op = optimizer.apply_gradients(grads)
    
    for var in tf.trainable_variables():
        tf.summary.histogram(var.op.name + "/values", var)
        
    for grad, var in grads:
        if grad is not None:
            tf.summary.histogram(var.op.name + "/gradients", grad)

# summary
accuracy_summary = tf.summary.scalar("accuracy", accuracy)

# %%
# merge all summary
tf.summary.histogram('hidden1/activations', hidden1)
tf.summary.histogram('hidden2/activations', hidden2)
merged = tf.summary.merge_all()

init = tf.global_variables_initializer()
saver = tf.train.Saver()

train_writer = tf.summary.FileWriter("models/dnn0/train", tf.get_default_graph())
test_writer = tf.summary.FileWriter("models/dnn0/test", tf.get_default_graph())

num_epochs = 50
batch_size = 128

# %% [markdown]
# ####  <span style="color:red">**Question 2.6.**</span> Train your network and report the resutls, and inspect the computational graph and visualize the gradients, hidden layers 1,2
#
# <div style="text-align: right"> <span style="color:red"></span> </div>

# %% [markdown]
# The **first** part of this sub-question requires you to write codes in the following cell.

# %%
with tf.Session() as sess:
    init.run()
    print("Epoch\tTrain accuracy\tValid accuracy")
    for epoch in range(num_epochs):
        for idx_start in range(0, X_train.shape[0], batch_size):
            idx_end = min(X_train.shape[0], idx_start + batch_size)
            X_batch, y_batch = X_train[idx_start:idx_end], y_train[idx_start:idx_end]
            sess.run(training_op, feed_dict={inputs: X_batch, labels: y_batch})
            
        summary_train, acc_train = sess.run([merged,accuracy], feed_dict={inputs:X_train, labels:y_train})
        summary_valid, acc_valid = sess.run([merged,accuracy], feed_dict={inputs:X_valid, labels:y_valid})
        
        train_writer.add_summary(summary_train, epoch)
        test_writer.add_summary(summary_valid, epoch)
        
        print("{}\t{}\t{}".format(epoch, acc_train, acc_valid))

    save_path = saver.save(sess, "models/dnn0.ckpt")
# Out:
# Epoch	Train accuracy	Valid accuracy
# 0	0.8111851811408997	0.8051666617393494
# 1	0.8441481590270996	0.8371666669845581
# 2	0.8542037010192871	0.8428333401679993
# 3	0.859666645526886	0.8483333587646484
# 4	0.8633703589439392	0.8506666421890259
# 5	0.867814838886261	0.8544999957084656
# 6	0.8721481561660767	0.85916668176651
# 7	0.8759815096855164	0.8604999780654907
# 8	0.8789814710617065	0.8631666898727417
# 9	0.8803889155387878	0.8658333420753479
# 10	0.881851851940155	0.8636666536331177
# 11	0.8825370073318481	0.8634999990463257
# 12	0.8833147883415222	0.8636666536331177
# 13	0.8841666579246521	0.8646666407585144
# 14	0.8864259123802185	0.8650000095367432
# 15	0.889037013053894	0.8663333058357239
# 16	0.8888518810272217	0.8683333396911621
# 17	0.8908703923225403	0.8688333630561829
# 18	0.8923147916793823	0.8693333268165588
# 19	0.8933888673782349	0.8711666464805603
# 20	0.8940370082855225	0.8711666464805603
# 21	0.8952407240867615	0.8721666932106018
# ...

# %% [markdown]
# The **second** part of this subquestion requires you use the Tensorboard, find out relevant visualizations and input them into the markdown cell below. (***Hint***: A software to capture the screen such as *Snipping Tools* in *Windows* may help).

# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir "./models/dnn0"
# Out:
# Reusing TensorBoard on port 6006 (pid 660), started 1 day, 0:44:46 ago. (Use '!kill 660' to kill it.)
#       <iframe id="tensorboard-frame-37d95bca4be15734" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-37d95bca4be15734");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# First hidden layer | Second hidden layer
# :-: | :-:
# [<img src="Figures/hidden1.png" width="350" align="left"/>] | [<img src="Figures/hidden2.png" width="350" align="left"/>]
#
# * *Parameter gradients*:
#
# First weight layer | Second weight layer | Last weight layer
# :-: | :-: | :-:
# [<img src="Figures/layer_1_weight_gradient.png" width="250" align="left"/>] | [<img src="Figures/layer_2_weight_gradient.png" width="250" align="left"/>] | [<img src="Figures/logits_weight_gradient.png" width="250" align="left"/>]

# %% [markdown]
# ## <span style="color:#0b486b">Part 3: Convolutional Neural Networks and Image Classification</span>
#
# **<div style="text-align: right"><span style="color:red"></span></div>**

# %% [markdown]
# **This part of the asssignment is designed to access your knowledge and coding skill with Tensorflow as well as hands-on experience with training Convolutional Neural Network (CNN).**

# %% [markdown]
# **The dataset we use for this part is a small animal dataset consisting of $2000$ images of cats, dogs, fishes and lions, each of which has 500 images. You can download the dataset at [download here](https://drive.google.com/file/d/1t5b-pNMK5-uIK6wZIIHBluLY7tPK0JzV/view?usp=sharing) and then decompress to the folder the folder `datasets\Animals` for you in the assignment folder.**
#
# **Your task is to build a CNN model using *TF 2.x* to classify these animals. You're provided with the module <span style="color:red">models.py</span>, which you can find in the assignment folder, with some of the following classes:**

# %% [markdown]
# 1. `AnimalsDatasetManager`: Support with loading and spliting the dataset into the train-val-test sets. It also help generate next batches for training. `AnimalsDatasetManager` will be passed to CNN model for training and testing.
# 2. `DefaultModel`: A base class for the CNN model.
# 3. `YourModel`: The class you'll need to implement to build the CNN model. It inherits some useful attributes and functions from the base class `DefaultModel`

# %% [markdown]
# Firstly, we need to run the following cells to load and preprocess the Animal dataset.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline
import models
from models import SimplePreprocessor, AnimalsDatasetManager, DefaultModel

# %%
def create_label_folder_dict(adir):
    sub_folders= [folder for folder in os.listdir(adir)
                  if os.path.isdir(os.path.join(adir, folder))]
    label_folder_dict= dict()
    for folder in sub_folders:
        item= {folder: os.path.abspath(os.path.join(adir, folder))}
        label_folder_dict.update(item)
    return label_folder_dict

# %%
label_folder_dict= create_label_folder_dict("./datasets/Animals")

# %%
# label_folder_dict

# %% [markdown]
# The below code helps to create a data manager that contains all relevant methods used to manage and process our experimental data.

# %%
sp = SimplePreprocessor(width=32, height=32)
data_manager = AnimalsDatasetManager([sp])
data_manager.load(label_folder_dict, verbose=100)
data_manager.process_data_label()
data_manager.train_valid_test_split()
# Out:
# cats 12500
# Processed 100/500
# Processed 200/500
# Processed 300/500
# Processed 400/500
# Processed 500/500
# dogs 12500
# Processed 100/500
# Processed 200/500
# Processed 300/500
# Processed 400/500
# Processed 500/500
# fishes 500
# Processed 100/500
# Processed 200/500
# Processed 300/500
# Processed 400/500
# Processed 500/500
# lions 500
# Processed 100/500
# Processed 200/500
# Processed 300/500
# Processed 400/500
# Processed 500/500

# %% [markdown]
# Note that the object `data_manager` has the attributes relating to *the training, validation, and testing sets* as shown belows. You can use them in training your developped models in the sequel.

# %%
print(data_manager.X_train.shape, data_manager.y_train.shape)
print(data_manager.X_valid.shape, data_manager.y_valid.shape)
print(data_manager.X_test.shape, data_manager.y_test.shape)
print(data_manager.classes)
# Out:
# (1600, 32, 32, 3) (1600,)
# (200, 32, 32, 3) (200,)
# (200, 32, 32, 3) (200,)
# ['cats' 'dogs' 'fishes' 'lions']

# %% [markdown]
# We now run the **default model** built in the **models.py** file which serves as a basic baseline to start the investigation. Follow the following steps to realize how to run a model and know the built-in methods associated to a model developped in the DefaultModel class.

# %% [markdown]
# We first initialize a default model from the DefaultModel class. Basically, we can define the relevant parameters of training a model including `num_classes`, `optimizer`, `learning_rate`, `batch_size`, and `num_epochs`.

# %%
network1 = DefaultModel(name='network1',
                       num_classes=len(data_manager.classes),
                       optimizer='sgd',
                       batch_size= 128,
                       num_epochs = 20,
                       learning_rate=0.5)

# %% [markdown]
# The method `build_cnn()` assists us in building your convolutional neural network. You can view the code (in the **models.py** file) of the model behind a default model to realize how simple it is. Additionally, the method `summary()` shows the architecture of a model.

# %%
network1.build_cnn()
network1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# ...

# %% [markdown]
# To train a model regarding to the datasets stored in `data_manager`, you can invoke the method `fit()` for which you can specify the batch size and number of epochs for your training.

# %%
network1.fit(data_manager, batch_size = 64, num_epochs = 20)
# Out:
# Train on 1600 samples, validate on 200 samples
# Epoch 1/20
# 1600/1600 [==============================] - ETA: 0s - loss: 1.3815 - acc: 0.2869WARNING:tensorflow:From C:\Users\ahhan\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_v1.py:2048: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# 1600/1600 [==============================] - 2s 1ms/sample - loss: 1.3815 - acc: 0.2869 - val_loss: 1.3897 - val_acc: 0.2600
# Epoch 2/20
# 1600/1600 [==============================] - 2s 1ms/sample - loss: 1.3845 - acc: 0.2663 - val_loss: 1.3870 - val_acc: 0.2350
# Epoch 3/20
# 1600/1600 [==============================] - 2s 1ms/sample - loss: 1.3882 - acc: 0.2425 - val_loss: 1.3869 - val_acc: 0.2500
# Epoch 4/20
# ...

# %% [markdown]
# Here you can compute the accuracy of your trained model with respect to a separate testing set.

# %%
network1.compute_accuracy(data_manager.X_test, data_manager.y_test)
# Out:
# 0.245

# %% [markdown]
# Below shows how you can inspect the training progress.

# %%
network1.plot_progress()

# %% [markdown]
# You can use the method `predict()` to predict labels for data examples in a test set.

# %%
network1.predict(data_manager.X_test[0:10])
# Out:
# array([3, 3, 3, 3, 3, 3, 3, 3, 3, 3], dtype=int64)

# %% [markdown]
# Finally, the method `plot_prediction()` visualizes the predictions for a test set in which several images are chosen to show the predictions.

# %%
network1.plot_prediction(data_manager.X_test, data_manager.y_test, data_manager.classes)

# %% [markdown]
# <span style="color:red">**Question 3.1.**</span> **After running the above cells to train the default model and observe the learning curve. Report your observation (i.e. did the model learn well? if not, what is the problem? what would you do to improve it?). Write your answer below.**
#
# <div style="text-align: right"> <span style="color:red"></span> </div>

# %% [markdown]
# <span style="color:#0b486b"> *#Your answer and observation here* </span>
#
# .....
#
# The model didnt really learnt well which is quite evident from the above graph.Training accuracy did not show any significant change across all epochs.The training accuracy is around 25% and the validation accuracy is also 25% which is very poor for a model. <br>
#
# As we can see in the network above, we haven't tuned the hyperparameters which is much needed as the model performs poorly. <br>
# The following parameters are important to tune:
# * Learning rate : The learning rate of the model is one of the important factor to be considered for optimization. Our model is trained on learning rate=0.5 which is very high in value. This will not help in achieving the local minima as they get skipped.For this, we will test our model on different learning rates and check for the performance of the model.
# * Adding few (1-2) dense layers after flatten() operation to make our model more deep. In that case we can also apply data augmentation operation to generate more data for training.
# * Epochs : More epocs means better learning for the model.But we have to be carefull about the overfitting problem. Its value differes with different models.For our case we can check with doubling our current epochs.

# %% [markdown]
# <span style="color:red">**Question 3.2.**</span> **Normally the first parameter to tune in Deep Learning is learning rate. In this question, you'll try running the default model with different learning rates (recommended in the list $[0.0001, 0.001, 0.005, 0.01]$) by entering the value in the cell below and run it. You should write your own code below for this learning rate tuning. Note that you can set the attribute `verbose` of the `DefaultModel` class to `False` for keeping the training silently without showing its details. Report the learning rates you tried along with the validation accuracy for each learning rate. What is the final learning rate that you'll use? Why?**
#
# <div style="text-align: right"> <span style="color:red"></span> </div>

# %%
lr = [0.0001,0.001,0.005,0.01] 
acc_list = []
for l_rate in lr:
    network2 = DefaultModel(name='network2',
                       num_classes=len(data_manager.classes),
                       optimizer='sgd',
                       batch_size= 128,
                       num_epochs = 20,
                       learning_rate=l_rate,
                       verbose=False)

    network2.build_cnn()
#     network2.summary()
    network2.fit(data_manager, batch_size = 64, num_epochs = 20)
    acc = network2.compute_accuracy(data_manager.X_test, data_manager.y_test)
    acc_list.append(acc)
#     network2.plot_progress()
acc_list
# Out:
# [0.265, 0.395, 0.535, 0.645]

# %%
import pandas as pd
accuracy_lr_df = pd.DataFrame(lr,acc_list).reset_index()
accuracy_lr_df.columns=['accruacy','learning rate']
accuracy_lr_df
# Out:
#    accruacy  learning rate
# 0     0.265         0.0001
# 1     0.395         0.0010
# 2     0.535         0.0050
# 3     0.645         0.0100

# %% [markdown]
# .....
#
# Learning rate is an important parameter to tune for training purposes. We usually use this parameter to optimize our model i.e. finding local/global minimum for our loss function. <br>
# From the table, we can see that for our model accuracy has increased with the increasing learning rate. In addition to this we are using only 20 epochs which does not help in optimizing parameters for lower learning rates.
#
# * For learning rate as low as 0.0001 and 0.0010 the model accuracy is very poor at around 26-27%. This is majorly due to the parameters not getting optimized with such a low learning and low number of epochs. <br>
#
# * **The final learning rate out of the tested one's i will use 0.01 which achieves an accuracy of 58%. In addition to this we can try higher learning rates for this model, but worrying about the overfitting at the same time.** <br> <br>

# %% [markdown]
# **For question 3.3 to 3.6, you'll need to write your own model in a way that makes it easy for you to experiment with different architectures as well as parameters. The goal is to be able to pass the parameters to initialize a new instance of `YourModel` to build different network architectures with different parameters. Below are descriptions of some parameters for `YourModel`, which you can find in function `__init__()` for the class `DefaultModel`:**

# %% [markdown]
# 1. `num_blocks`: an integer specifying the number of blocks in our network. Each block has the pattern `[conv, batch norm, activation, conv, batch norm, activation, mean pool, dropout]`. All convolutional layers have filter size $(3, 3)$, strides $(1, 1)$ and 'SAME' padding, and all mean pool layers have strides $(2, 2)$ and 'SAME' padding. The network will consists of a few blocks before applying a linear layer to output the logits for the softmax layer.
#
# 2. `feature_maps`: the number of feature maps in the first block of the network. The number of feature_maps will double in each of the following block. To make it convenient for you, we already calculated the number of feature maps for each block for you in line $106$
# 3. `drop_rate`: the keep probability for dropout. Setting `drop_rate` to $0.0$ means not using dropout.
# 4. `batch_norm`: the batch normalization function is used or not. Setting `batch_norm` to `None` means not using batch normalization.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models

# %% [markdown]
# <span style="color:red">**Question 3.3.**</span> **Write the code of the `YourModel` class here. Note that this class will inherit from the `DefaultModel` class. You'll only need to re-write the code for the `build_cnn` method for the `YourModel` class from the cell below which is inherited from the `DefaultModel` class.**
#
# <div style="text-align: right"> <span style="color:red"></span> </div>

# %%
class YourModel(DefaultModel):
    def __init__(self,
                 name='network1',
                 width=32, height=32, depth=3,
                 num_blocks=2,
                 feature_maps=32,
                 num_classes=4, 
                 drop_rate=0.2,
                 batch_norm = None,
                 is_augmentation = False,
                 activation_func='relu',
                 optimizer='adam',
                 batch_size=10,
                 num_epochs= 20,
                 learning_rate=0.0001,
                 verbose= True):
        super(YourModel, self).__init__(name, width, height, depth, num_blocks, feature_maps, num_classes, drop_rate, batch_norm, is_augmentation, 
                                        activation_func, optimizer, batch_size, num_epochs, learning_rate, verbose)
    
    def build_cnn(self):
        #Insert your code here
        self.model = models.Sequential()
        
#         length = len(self.feature_maps)
        
#         print(self.feature_maps)
        for i in range(0,len(self.feature_maps)):
        
            self.model.add(layers.Conv2D(self.feature_maps[i], (3,3), padding='same', activation=self.activation_func, 
                                         input_shape=(32,32,3)))
            if self.batch_norm is not None:
                self.model.add(layers.BatchNormalization(momentum=0.9))
                
            self.model.add(layers.Conv2D(self.feature_maps[i], (3,3), padding='same', activation=self.activation_func))
            
            if self.batch_norm is not None:
                self.model.add(layers.BatchNormalization(momentum=0.9))
                
            self.model.add(layers.AveragePooling2D(pool_size=(2, 2), padding='same'))
            
            self.model.add(layers.Dropout(rate=self.drop_rate))
        
        self.model.add(layers.Flatten())
        
#         self.model.add(layers.Dense(units=64, activation='relu'))
#         self.model.add(layers.Dense(units = 32, activation='relu'))
        self.model.add(layers.Dense(self.num_classes, activation='softmax'))
        
        self.model.compile(optimizer=self.optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# <span style="color:red">**Question 3.4.**</span> **Once writing your own models, you should be able to use it to experiment with dropout or batch normalization. In this question, you'll use your model to finetune the dropout rate. Report the `drop_rate` rates you tried along with the validation accuracy for each rate (recomended range: 0.2 to 0.5). What is
# the final `drop_rate` rate that you'll use? Did dropout improve performance? Did it help reduce overfitting? Note that in this experiment, you should set `batch_norm` to `None`, meaning that we do not use the batch normalization.**
#
# <div style="text-align: right"> <span style="color:red"></span> </div>

# %% [markdown]
# .....
#
# * I have used drop rates from 0.0 to 0.5
# * 0.0 was used to check the default state of our model. For no drop rate if we see the summary graph below both train and validation accuracy show an increase for the initial epochs. For higher epochs the validation accuracy starts to lower while training accuracy keeps increasing. This signifies that our model is experiencing overfitting with more epochs.
#
# * The final drop out value that i would go ahead with is 0.2. At this dropout value the accuracy has increased to 68.5% from 66%. Summary plot also shows that both train and validation accuracies show a positive growth with increasing epochs.
#
# * Introducing drop out rate is one of the important and powerful regularization technique in deep learning.<br>This is a technique where randomly selected neurons are ignored during training that is their contribution to the forward propagation is temporarily disabled.<br>
#
# * Clearly, the graphs show us that choosing the right rate is important as then the model will under learn the dataset.

# %%
drop_out_rates = [0.0,0.2,0.3,0.4,0.5]
drop_accuracy = []
for drop_rate in drop_out_rates:
    drop_out_network = YourModel(name='network1',
                         feature_maps=32,
                         num_classes=len(data_manager.classes),
                         num_blocks=4,
                         drop_rate= drop_rate, # enter your final dropout rate value here
                         batch_norm=None,     
                         optimizer='adam',
                         learning_rate= 0.001,
                         verbose=False)
    drop_out_network.build_cnn()
#     drop_out_network.summary()

    drop_out_network.fit(data_manager, batch_size = 64, num_epochs = 20)
    acc = drop_out_network.compute_accuracy(data_manager.X_test, data_manager.y_test)
    drop_accuracy.append(acc)
    print("For drop rate {} test accuracy is {}".format(drop_rate,acc))
    drop_out_network.plot_progress()
# Out:
# For drop rate 0.0 test accuracy is 0.6700000166893005
# For drop rate 0.2 test accuracy is 0.7350000143051147
# For drop rate 0.3 test accuracy is 0.7099999785423279
# For drop rate 0.4 test accuracy is 0.6700000166893005
# For drop rate 0.5 test accuracy is 0.6899999976158142

# %%
accuracy_droprate_df = pd.DataFrame(drop_accuracy,drop_out_rates).reset_index()
accuracy_droprate_df.columns=['drop_rate','accuracy_list']
accuracy_droprate_df
# Out:
#    drop_rate  accuracy_list
# 0        0.0          0.670
# 1        0.2          0.735
# 2        0.3          0.710
# 3        0.4          0.670
# 4        0.5          0.690

# %% [markdown]
# <span style="color:red">**Question 3.5.**</span> **Now, let's try using batch normalization. What is the validation and test result? Does it improve the model? How does it compare to the model using dropout? To have a fair comparison, in this experiment, we set `drop_rate=0` to not use the dropout.**
#
# <div style="text-align: right"> <span style="color:red"></span> </div>

# %% [markdown]
# ..... <br>
# Here we have now tried using batch normalization after activation functions.When used Batch Normalization alone, we could get results as shown by the below summary graph, where we can see that the loss of training is going lesser and lesser wherein at the end of the epochs its going to 0. That is overfitting the data. Training accuracy and validation showed increasing trend for initial epochs i.e. 10 , but post that the validation accuracy has dropped which hints at our model overfitting.<br>
# Final train accuracy achieved: 98.56%, validation accuracy = 68% and testing accuracy = 78.5%
# Batch normalization works best with high batch size and it will give different results with Training data and the test data. <br>
# Batch normalization will overfit the data when there is improper calculation of mean and variance which happens when we have lower batch size.

# %%
batch_norm_network = YourModel(name='network4',
                     feature_maps=32,
                     num_classes=len(data_manager.classes),
                     num_blocks=4,
                     drop_rate= 0, 
                     batch_norm=True, #do batch norm    
                     optimizer='adam',
                     learning_rate= 0.001)

batch_norm_network.build_cnn()
batch_norm_network.summary()
batch_norm_network.fit(data_manager, batch_size = 64, num_epochs = 20)
print("Testing accuracy is : {}".format(batch_norm_network.compute_accuracy(data_manager.X_test, data_manager.y_test)))
batch_norm_network.plot_progress()
# Out:
# Model: "sequential_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_60 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_61 (Conv2D)           (None, 32, 32, 32)        9248
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# average_pooling2d_30 (Averag (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_62 (Conv2D)           (None, 16, 16, 64)        18496
# ...

# %% [markdown]
# <span style="color:red">**Question 3.6.**</span> **Finally, you should try to train the best model by trying different configurations for `num_blocks`, `feature_maps`, `optimizer`, `learning_rate`, `batch_size`, `keep_prob` and `batch_norm`. Briefly report the experiments that you try and your observation in the answer below. Also, run the cells below with the best configuration you found.**
#
# <div style="text-align: right"> <span style="color:red"></span> </div>

# %% [markdown]
# What we know: <br>
#
# * Learning rate of 0.01 is better than 0.0001. So we will use lr = 0.01
# * Drop rate of 0.2 is the best to limit overfitting i.e keep_prob = 0.8
# * We will also implement with batch_norm = True, and we will change num_blocks and optimizers = adam,adagrad and rmsprop.

# %% [markdown]
# **For batch_norm = True**

# %%
num_blocks = [2,4]
df_true = pd.DataFrame(columns=["num_blocks", "optimizer","accuracy"])
for num_block in num_blocks:
    optimizer = ['adam','adagrad','rmsprop']
    for optimizer in optimizer:
        batch_norm_network_1 = YourModel(name='network4',
                             feature_maps=32,
                             num_classes=len(data_manager.classes),
                             num_blocks=num_block,
                             drop_rate= 0.2, 
                             batch_norm=True,   
                             optimizer=optimizer,
                             learning_rate= 0.01)

        batch_norm_network_1.build_cnn()
#         batch_norm_network_1.summary()
        batch_norm_network_1.fit(data_manager, batch_size = 64, num_epochs = 20)
        acc = batch_norm_network_1.compute_accuracy(data_manager.X_test, data_manager.y_test)
        print("Testing accuracy is : {} for num_blocks={} and optmizer {}"
              .format(acc,num_block,optimizer))
        batch_norm_network_1.plot_progress()
        df_true = df_true.append({'num_blocks': num_block,'optimizer':optimizer,'accuracy':acc}, ignore_index=True)
# Out:
# Train on 1600 samples, validate on 200 samples
# Epoch 1/20
# 1600/1600 [==============================] - 4s 2ms/sample - loss: 2.9989 - acc: 0.4444 - val_loss: 3.8067 - val_acc: 0.2950
# Epoch 2/20
# 1600/1600 [==============================] - 4s 2ms/sample - loss: 1.8394 - acc: 0.5462 - val_loss: 1.5858 - val_acc: 0.5150
# Epoch 3/20
# 1600/1600 [==============================] - 4s 2ms/sample - loss: 1.4627 - acc: 0.5794 - val_loss: 1.4796 - val_acc: 0.5550
# Epoch 4/20
# 1600/1600 [==============================] - 4s 2ms/sample - loss: 1.1504 - acc: 0.5987 - val_loss: 1.1415 - val_acc: 0.6000
# Epoch 5/20
# 1600/1600 [==============================] - 4s 2ms/sample - loss: 1.0847 - acc: 0.6356 - val_loss: 1.1558 - val_acc: 0.5700
# Epoch 6/20
# 1600/1600 [==============================] - 4s 2ms/sample - loss: 0.9146 - acc: 0.6687 - val_loss: 1.3022 - val_acc: 0.4500
# Epoch 7/20
# ...

# %%
df_true
# Out:
#   num_blocks optimizer  accuracy
# 0          2      adam     0.675
# 1          2   adagrad     0.730
# 2          2   rmsprop     0.655
# 3          4      adam     0.670
# 4          4   adagrad     0.735
# 5          4   rmsprop     0.650

# %% [markdown]
# <span style="color:#0b486b"> #*Write your answer and discussion here* </span>
#
# In the previous steps, we have tried our model with different learning rates where after observing we found that 0.01 performs the best on the model. <br>
# Next we created our model which was overfitting the training the data giving us accuracy of almost 99%. For tackling this issue, we tried drop out and batch normalization techniques were we found the best drop out rate to be 0.2 which gave us a better testing accuracy and reduced overfitting. <br>
# - learning rate = 0.01
# - drop_rate = 0.2
# - batch_norm = True
# - num_blocks = [2,4]
# - optimizer = ['adam','adagrad','rmsprop'] <br><br>
#
# From the above dataframe we can conclude that num_blocks=4 is better suited for out network and adagrad as an optimizer would be a good option

# %% [markdown]
# <span style="color:red">**Question 3.7.**</span> **We now try to apply data augmentation to improve the performance. Extend the code of the class `YourModel` so that if the attribute `is_augmentation` is set to `True`, we apply the data augmentation.**
#
# <div style="text-align: right"> <span style="color:red"></span> </div>

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# Wtire your code in the cell below. Hint that you can rewrite the code of `fit` method to apply the data augmentation. In addition, you can copy the code of `build_cnn` method above to reuse here.

# %%
class YourModel(DefaultModel):
    def __init__(self,
                 name='network1',
                 width=32, height=32, depth=3,
                 num_blocks=2,
                 feature_maps=32,
                 num_classes=4, 
                 drop_rate=0.2,
                 batch_norm = None,
                 is_augmentation = False,
                 activation_func='relu',
                 optimizer='adam',
                 batch_size=10,
                 num_epochs= 20,
                 learning_rate=0.0001):
        super(YourModel, self).__init__(name, width, height, depth, num_blocks, feature_maps, num_classes, drop_rate,
                                        batch_norm, is_augmentation, 
                                        activation_func, optimizer, batch_size, num_epochs, learning_rate)
    
    def build_cnn(self):
        self.model = models.Sequential()
        
#         length = len(self.feature_maps)
        
#         print(self.feature_maps)
        for i in range(0,len(self.feature_maps)):
        
            self.model.add(layers.Conv2D(self.feature_maps[i], (3,3), padding='same', activation=self.activation_func, 
                                         input_shape=(32,32,3)))
            if self.batch_norm is not None:
                self.model.add(layers.BatchNormalization(momentum=0.9))
                
            self.model.add(layers.Conv2D(self.feature_maps[i], (3,3), padding='same', activation=self.activation_func))
            
            if self.batch_norm is not None:
                self.model.add(layers.BatchNormalization(momentum=0.9))
                
            self.model.add(layers.AveragePooling2D(pool_size=(2, 2), padding='same'))
            
            self.model.add(layers.Dropout(rate=self.drop_rate))
        
        self.model.add(layers.Flatten())
        
#         self.model.add(layers.Dense(units=64, activation='relu'))
#         self.model.add(layers.Dense(units = 32, activation='relu'))
        self.model.add(layers.Dense(self.num_classes, activation='softmax'))
        
        self.model.compile(optimizer=self.optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    
    def fit(self, data_manager, batch_size=None, num_epochs=None):
        
        batch_size = self.batch_size if batch_size is None else batch_size
        num_epochs = self.num_epochs if num_epochs is None else num_epochs
        aug = ImageDataGenerator(rotation_range=5, width_shift_range=0.1, height_shift_range=0.1, shear_range=0.1,
                                 zoom_range=0.1, horizontal_flip=True, fill_mode="nearest")
        
        self.model.compile(optimizer=self.optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
        self.history = self.model.fit_generator(aug.flow(x = data_manager.X_train, 
                                                         y = data_manager.y_train,batch_size=batch_size),
                                                validation_data =(data_manager.X_valid, data_manager.y_valid),
                                                epochs = num_epochs,verbose= self.verbose)

# %% [markdown]
# <span style="color:red">**Question 3.8.**</span> **Leverage the data augmentation with the best model you found before and try to observe if you can really boost the performance.**
#
# <div style="text-align: right"> <span style="color:red"></span> </div>

# %% [markdown]
# <span style="color:#0b486b"> #*Write your answer and observation here* </span>
#
# .....
#
# * Data augmentation is an automatic way to boost the number of different images you will use to train your Deep learning algorithms.
#
# * It increases the ability of the model to generalize more on the new dataset. We perform transformations like shifts,flips,zooms and etc.
#
# * After we run the model with augmentation our training accuracy is 80.37%, validation accuracy at 72% and testing accuracy at 70%. Overfitting problem has been solved and a test accuracy of 72% is good enough.
# * For implementing the best model on this network, we used the same parameters as in the best model and created augmentation network model. <br>

# %%
augmentation_network = YourModel(name='network5',
                     feature_maps=32,
                     num_classes=len(data_manager.classes),
                     num_blocks=4,
                     drop_rate= 0.2,
                     batch_norm=True,
                     is_augmentation= True,
                     optimizer='adagrad',
                     learning_rate= 0.01)
augmentation_network.build_cnn()
# augmentation_network.summary()

# %%
augmentation_network.fit(data_manager, batch_size = 64, num_epochs = 20)
print(augmentation_network.compute_accuracy(data_manager.X_test, data_manager.y_test))
augmentation_network.plot_progress()
# Out:
# WARNING:tensorflow:From <ipython-input-44-1dbc4db3a652>:58: Model.fit_generator (from tensorflow.python.keras.engine.training_v1) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/20
# 25/25 [==============================] - 6s 227ms/step - batch: 12.0000 - size: 64.0000 - loss: 1.2485 - acc: 0.5006 - val_loss: 1.7742 - val_acc: 0.2350
# Epoch 2/20
# 25/25 [==============================] - 5s 208ms/step - batch: 12.0000 - size: 64.0000 - loss: 0.9945 - acc: 0.5781 - val_loss: 1.2229 - val_acc: 0.4950
# Epoch 3/20
# 25/25 [==============================] - 5s 204ms/step - batch: 12.0000 - size: 64.0000 - loss: 0.8478 - acc: 0.6413 - val_loss: 1.1955 - val_acc: 0.5250
# Epoch 4/20
# 25/25 [==============================] - 5s 210ms/step - batch: 12.0000 - size: 64.0000 - loss: 0.8000 - acc: 0.6600 - val_loss: 0.7806 - val_acc: 0.6550
# Epoch 5/20
# ...

# %% [markdown]
# <span style="color:red">**Question 3.9.**</span> **Attack your best obtained model with PGD and FGSM attacks with $\epsilon= 0.0313, k=20, \eta= 0.005$ on the testing set. Write the code for the attacks and report the robust accuracies. Also choose a random set of 20 clean images in the testing set and visualize the original and attacked images.**
#
# <div style="text-align: right"> <span style="color:red"></span> </div>

# %%
# !pip uninstall -y cleverhans
# !pip install git+https://github.com/tensorflow/cleverhans.git#egg=cleverhans --no-cache-dir

# %%
import numpy as np
import cleverhans
from cleverhans_future.tf2.attacks import projected_gradient_descent, fast_gradient_method, momentum_iterative_method

# %%
augmentation_network.summary()
# Out:
# Model: "sequential_35"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_104 (Conv2D)          (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization_44 (Batc (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_105 (Conv2D)          (None, 32, 32, 32)        9248
# _________________________________________________________________
# batch_normalization_45 (Batc (None, 32, 32, 32)        128
# _________________________________________________________________
# average_pooling2d_52 (Averag (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_106 (Conv2D)          (None, 16, 16, 64)        18496
# ...

# %%
flat_layer = augmentation_network.model.get_layer('flatten_17')  
flat_hidden = flat_layer.output
output_layer = augmentation_network.model.get_layer('dense_17')
output_weight = output_layer.weights[0]
print(flat_hidden.shape, output_weight.shape)
output_logits = tf.matmul(flat_hidden, output_weight)
print(output_logits.shape)
animal_logits = tf.keras.Model(augmentation_network.model.input, output_logits)
# Out:
# (?, 1024) (1024, 4)
# (?, 4)

# %%
X_pgd = projected_gradient_descent(model_fn=animal_logits, x = data_manager.X_test.astype(np.float32), eps=0.0313, eps_iter=0.005, nb_iter=20, norm=np.inf)
X_fsgm = fast_gradient_method(model_fn = animal_logits, x = data_manager.X_test.astype(np.float32), eps = 0.0313, norm=np.inf )
y_pgd = np.argmax(animal_logits.predict(X_pgd,steps = 1), 1)
y_fsgm = np.argmax(animal_logits.predict(X_fsgm,steps=1), 1)

# %%
print("PGD: ")
for i in range(0,20):
    print("True label: {}, adversarial label: {}".format(data_manager.classes[np.array(data_manager.y_test)][i],data_manager.classes[np.array(y_pgd)][i] ))
# Out:
# PGD:
# True label: dogs, adversarial label: dogs
# True label: cats, adversarial label: lions
# True label: lions, adversarial label: lions
# True label: lions, adversarial label: cats
# True label: dogs, adversarial label: cats
# True label: fishes, adversarial label: fishes
# True label: lions, adversarial label: dogs
# True label: dogs, adversarial label: lions
# True label: cats, adversarial label: cats
# True label: lions, adversarial label: lions
# True label: lions, adversarial label: lions
# True label: cats, adversarial label: cats
# True label: cats, adversarial label: lions
# True label: lions, adversarial label: lions
# True label: fishes, adversarial label: fishes
# True label: fishes, adversarial label: fishes
# True label: lions, adversarial label: lions
# True label: lions, adversarial label: lions
# True label: lions, adversarial label: lions
# True label: dogs, adversarial label: dogs

# %%
print("For Fsgm:")
for i in range(0,20):
    print("True label: {}, adversarial label: {}".format(data_manager.classes[np.array(data_manager.y_test)][i],data_manager.classes[np.array(y_fsgm)][i] ))
# Out:
# For Fsgm:
# True label: dogs, adversarial label: dogs
# True label: cats, adversarial label: cats
# True label: lions, adversarial label: lions
# True label: lions, adversarial label: cats
# True label: dogs, adversarial label: cats
# True label: fishes, adversarial label: fishes
# True label: lions, adversarial label: lions
# True label: dogs, adversarial label: lions
# True label: cats, adversarial label: cats
# True label: lions, adversarial label: lions
# True label: lions, adversarial label: lions
# True label: cats, adversarial label: dogs
# True label: cats, adversarial label: lions
# True label: lions, adversarial label: lions
# True label: fishes, adversarial label: lions
# True label: fishes, adversarial label: fishes
# True label: lions, adversarial label: lions
# True label: lions, adversarial label: lions
# True label: lions, adversarial label: lions
# True label: dogs, adversarial label: dogs

# %%
def plot_image_grid(image, label, image_shape):
        fig, axes = plt.subplots(4, 5, figsize=(1.5*5,2*4))
        for i in range(20):
            ax = axes[i//5, i%5]
            ax.imshow(image[i].reshape(image_shape))
            ax.set_title('Label: {}'.format(data_manager.classes[label[i]]))
        plt.tight_layout()
        plt.axis('off')

# %%
plot_image_grid(data_manager.X_test[:20], data_manager.y_test[:20], (32,32,3))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %%
X_pgd_top_20 = projected_gradient_descent(model_fn=animal_logits, x = data_manager.X_test[:20].astype(np.float32), eps=0.0313, eps_iter=0.005, nb_iter=20, norm=np.inf)
y_pgd_top_20 = np.argmax(animal_logits.predict(X_pgd_top_20,steps=1), 1)

# %%
plot_image_grid(tf.keras.backend.get_value(X_pgd_top_20),y_pgd_top_20,(32,32,3))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %%
X_fsgm_top_20 = fast_gradient_method(model_fn=animal_logits, x = data_manager.X_test[:20].astype(np.float32), eps=0.0313, norm=np.inf)
y_fsgm_top_20 = np.argmax(animal_logits.predict(X_fsgm_top_20,steps=1), 1)

# %%
plot_image_grid(tf.keras.backend.get_value(X_fsgm_top_20),y_fsgm_top_20,(32,32,3))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %%
import sklearn
accuracy_pgd = sklearn.metrics.accuracy_score(data_manager.y_test,y_pgd)
accuracy_fsgm = sklearn.metrics.accuracy_score(data_manager.y_test,y_fsgm)

# %%
print('Accuracy after PGD attack :',+(accuracy_pgd*100))
print('Accuracy after FSGM attack : ',+(accuracy_fsgm*100))
# Out:
# Accuracy after PGD attack : 55.00000000000001
# Accuracy after FSGM attack :  57.49999999999999

# %% [markdown]
# <span style="color:red">**Question 3.10.**</span> **Train a robust model using adversarial training with PGD $\{\epsilon= 0.0313, k=10, \eta= 0.005\}$. Write the code for the adversarial training and report the robust accuracies. After finishing the training, you need to store your best robust model in the folder `./models` and load the model to evaluate the robust accuracies for PGD and FGSM attacks with $\epsilon= 0.0313, k=20, \eta= 0.005$ on the testing set.**
#
# <div style="text-align: right"> <span style="color:red"></span> </div>

# %%
augmentation_network.summary()
# Out:
# Model: "sequential_35"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_104 (Conv2D)          (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization_44 (Batc (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_105 (Conv2D)          (None, 32, 32, 32)        9248
# _________________________________________________________________
# batch_normalization_45 (Batc (None, 32, 32, 32)        128
# _________________________________________________________________
# average_pooling2d_52 (Averag (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_106 (Conv2D)          (None, 16, 16, 64)        18496
# ...

# %% [markdown]
# ---
# **<div style="text-align: center"> <span style="color:black"></span> </div>**
